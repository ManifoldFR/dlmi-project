# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import matplotlib.pyplot as plt
from utils.loaders import DriveDataset, make_train_transform

# %%
transform = make_train_transform(False)

train_dataset = DriveDataset("data/drive/training",
                             transforms=transform,
                             train=True)

# %% [markdown]
# # Testing datasets and augmentations

# %%
img, mask = train_dataset[0]

fig = plt.figure(figsize=(9, 5))
plt.subplot(121)
plt.imshow(img)

plt.subplot(122)
plt.imshow(mask)

plt.tight_layout()
